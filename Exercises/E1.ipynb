# %% [markdown]
# # E1. Missing data and aggregations exercises

# %% [markdown]
# ## 1. Find missing values

# %% [markdown]
# ###  a) Read in the file "student-mat-missing-data.csv" into a Pandas DataFrame

# %%
import pandas as pd


df = pd.read_csv("../Data/student-mat-missing-data.csv")

df
# Out:
#      Unnamed: 0 school sex   age address famsize Pstatus  Medu  Fedu  \
# 0             0     GP   F  18.0       U     GT3       A     4     4
# 1             1     GP   F  17.0       U     GT3       T     1     1
# 2             2     GP   F  15.0       U     LE3       T     1     1
# 3             3     GP   F  15.0       U     GT3       T     4     2
# 4             4     GP   F  16.0       U     GT3       T     3     3
# ..          ...    ...  ..   ...     ...     ...     ...   ...   ...
# 390         390     MS   M  20.0       U     LE3       A     2     2
# 391         391     MS   M  17.0       U     LE3       T     3     1
# 392         392     MS   M  21.0       R     GT3       T     1     1
# 393         393     MS   M  18.0       R     LE3       T     3     2
# 394         394     MS   M  19.0       U     LE3       T     1     1
#
#          Mjob  ... famrel freetime goout  Dalc  Walc  health absences  G1  G2  \
# 0     at_home  ...    4.0      3.0   4.0     1     1     3.0      6.0   5   6
# 1     at_home  ...    5.0      3.0   3.0     1     1     3.0      4.0   5   5
# 2     at_home  ...    4.0      3.0   2.0     2     3     3.0     10.0   7   8
# 3      health  ...    3.0      2.0   2.0     1     1     5.0      2.0  15  14
# 4       other  ...    4.0      3.0   2.0     1     2     5.0      4.0   6  10
# ..        ...  ...    ...      ...   ...   ...   ...     ...      ...  ..  ..
# 390  services  ...    5.0      5.0   4.0     4     5     4.0     11.0   9   9
# 391  services  ...    2.0      4.0   5.0     3     4     2.0      3.0  14  16
# 392     other  ...    5.0      5.0   3.0     3     3     3.0      3.0  10   8
# 393  services  ...    4.0      4.0   1.0     3     4     5.0      0.0  11  12
# 394     other  ...    3.0      2.0   3.0     3     3     5.0      5.0   8   9
#
#      G3
# 0     6
# 1     6
# 2    10
# 3    15
# 4    10
# ..   ..
# 390   9
# 391  16
# 392   7
# 393  10
# 394   9
#
# [395 rows x 34 columns]

# %% [markdown]
# ### b) Do some initial explorations with the methods to get an understanding of the dataset:
#
# head(), info(), describe(), value_counts(), unique(), columns()

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'school', 'sex', 'age', 'address', 'famsize', 'Pstatus',
#        'Medu', 'Fedu', 'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime',
#        'studytime', 'failures', 'schoolsup', 'famsup', 'paid', 'activities',
#        'nursery', 'higher', 'internet', 'romantic', 'famrel', 'freetime',
#        'goout', 'Dalc', 'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %% [markdown]
# ###  c) Create a function that takes in a DataFrame as input parameter and plots a barplot with the columns that have missing values. Put this function into a file called data_utils.py. When you come across more useful functions, you can store them in your data_utils module.

# %%
# data_utils.py funktion plot_null_columns

# %% [markdown]
# ### d) Now import your function from the module data_utils and use it to visualize NaNs in your dataset.

# %%
from sys import path
path.append("..")

from data_utils import plot_null_columns

plot_null_columns(df)

# %% [markdown]
# ### e) Find all rows where the freetime is NaN.

# %%
df[df["freetime"].isnull()]
# Out:
#      Unnamed: 0 school sex   age address famsize Pstatus  Medu  Fedu  \
# 87           87     GP   F  15.0       U     GT3       T     4     2
# 99           99     GP   F  16.0       U     GT3       T     4     3
# 130         130     GP   F  15.0       R     GT3       T     3     4
# 149         149     GP   M  15.0       U     LE3       A     2     1
# 151         151     GP   M  16.0       U     LE3       T     2     1
# 160         160     GP   M   NaN     NaN     LE3       T     2     1
# 191         191     GP   F   NaN     NaN     GT3       T     1     1
# 257         257     GP   M  19.0       U     LE3       A     4     3
# 276         276     GP   F   NaN     NaN     GT3       A     3     2
# 293         293     GP   F   NaN     NaN     LE3       T     3     1
# 308         308     GP   M  19.0       R     GT3       T     3     3
# 330         330     GP   M  18.0       U     LE3       T     2     2
# 343         343     GP   F  17.0       U     GT3       A     2     2
# 359         359     MS   F  18.0       U     LE3       T     1     1
# 372         372     MS   F  17.0       U     GT3       T     2     2
# 385         385     MS   F   NaN     NaN     GT3       T     2     2
#
#          Mjob  ... famrel freetime goout  Dalc  Walc  health absences  G1  G2  \
# 87      other  ...    5.0      NaN   3.0     1     3     1.0      4.0  13  14
# 99      other  ...    5.0      NaN   5.0     1     1     3.0      0.0   7   9
# 130  services  ...    4.0      NaN   2.0     2     2     5.0      0.0  12   0
# 149  services  ...    4.0      NaN   5.0     2     5     5.0      0.0   8   9
# 151   at_home  ...    4.0      NaN   4.0     3     5     5.0      6.0  12  13
# 160   at_home  ...    NaN      NaN   NaN     2     2     NaN      NaN   7   6
# 191   at_home  ...    NaN      NaN   NaN     1     1     NaN      NaN   8   8
# 257  services  ...    4.0      NaN   1.0     1     1     1.0     12.0  11  11
# 276     other  ...    NaN      NaN   NaN     1     1     NaN      NaN  10   9
# 293  services  ...    NaN      NaN   NaN     1     1     NaN      NaN  18  18
# 308     other  ...    4.0      NaN   3.0     1     2     5.0      0.0  15  12
# 330     other  ...    4.0      NaN   5.0     2     4     5.0      2.0   9   8
# 343   at_home  ...    3.0      NaN   1.0     1     2     4.0      0.0   9   8
# 359   at_home  ...    5.0      NaN   2.0     1     1     4.0      0.0  18  16
# 372     other  ...    3.0      NaN   3.0     1     1     3.0      8.0  13  11
# 385   at_home  ...    NaN      NaN   NaN     1     3     NaN      NaN  10   9
#
#      G3
# 87   14
# 99    8
# 130   0
# 149  10
# 151  14
# 160   0
# 191   9
# 257  11
# 276   9
# 293  18
# 308  12
# 330   8
# 343   0
# 359  16
# 372  11
# 385  10
#
# [16 rows x 34 columns]

# %% [markdown]
# ### f) Find all rows where the freetime or the age is NaN.

# %%
#df2 = pd.merge(df[df["freetime"].isnull()], df[df["age"].isnull()], "outer").sort_values("Unnamed: 0")
df2 = df[df["freetime"].isnull() | df["age"].isnull()]
df2
# Out:
#      Unnamed: 0 school sex   age address famsize Pstatus  Medu  Fedu  \
# 20           20     GP   M   NaN       U     GT3       T     4     3
# 71           71     GP   M   NaN       U     GT3       T     4     2
# 87           87     GP   F  15.0       U     GT3       T     4     2
# 99           99     GP   F  16.0       U     GT3       T     4     3
# 102         102     GP   M   NaN       U     GT3       T     4     4
# 106         106     GP   F   NaN       U     GT3       T     2     2
# 121         121     GP   M   NaN       U     GT3       T     2     2
# 130         130     GP   F  15.0       R     GT3       T     3     4
# 149         149     GP   M  15.0       U     LE3       A     2     1
# 151         151     GP   M  16.0       U     LE3       T     2     1
# 160         160     GP   M   NaN     NaN     LE3       T     2     1
# 188         188     GP   F   NaN       U     GT3       A     3     3
# 191         191     GP   F   NaN     NaN     GT3       T     1     1
# 214         214     GP   F   NaN       R     LE3       T     4     4
# 257         257     GP   M  19.0       U     LE3       A     4     3
# 270         270     GP   F   NaN       U     GT3       T     3     3
# 276         276     GP   F   NaN     NaN     GT3       A     3     2
# 293         293     GP   F   NaN     NaN     LE3       T     3     1
# 308         308     GP   M  19.0       R     GT3       T     3     3
# 330         330     GP   M  18.0       U     LE3       T     2     2
# 343         343     GP   F  17.0       U     GT3       A     2     2
# 348         348     GP   F   NaN       U     GT3       T     4     3
# 359         359     MS   F  18.0       U     LE3       T     1     1
# 372         372     MS   F  17.0       U     GT3       T     2     2
# 385         385     MS   F   NaN     NaN     GT3       T     2     2
#
#          Mjob  ... famrel freetime goout  Dalc  Walc  health absences  G1  G2  \
# 20    teacher  ...    4.0      4.0   1.0     1     1     1.0      0.0  13  14
# 71      other  ...    3.0      3.0   3.0     1     1     3.0      0.0  10  10
# 87      other  ...    5.0      NaN   3.0     1     3     1.0      4.0  13  14
# 99      other  ...    5.0      NaN   5.0     1     1     3.0      0.0   7   9
# 102  services  ...    5.0      3.0   3.0     1     1     5.0      4.0  10  13
# 106     other  ...    5.0      1.0   2.0     1     1     3.0      8.0   7   8
# 121  services  ...    5.0      5.0   4.0     1     2     5.0      6.0  16  14
# 130  services  ...    4.0      NaN   2.0     2     2     5.0      0.0  12   0
# 149  services  ...    4.0      NaN   5.0     2     5     5.0      0.0   8   9
# 151   at_home  ...    4.0      NaN   4.0     3     5     5.0      6.0  12  13
# 160   at_home  ...    NaN      NaN   NaN     2     2     NaN      NaN   7   6
# 188    health  ...    3.0      3.0   3.0     1     3     3.0      6.0   8   7
# 191   at_home  ...    NaN      NaN   NaN     1     1     NaN      NaN   8   8
# 214  services  ...    5.0      2.0   1.0     1     2     3.0     12.0   8  10
# 257  services  ...    4.0      NaN   1.0     1     1     1.0     12.0  11  11
# 270     other  ...    4.0      3.0   5.0     3     3     5.0     15.0   9   9
# 276     other  ...    NaN      NaN   NaN     1     1     NaN      NaN  10   9
# 293  services  ...    NaN      NaN   NaN     1     1     NaN      NaN  18  18
# 308     other  ...    4.0      NaN   3.0     1     2     5.0      0.0  15  12
# 330     other  ...    4.0      NaN   5.0     2     4     5.0      2.0   9   8
# 343   at_home  ...    3.0      NaN   1.0     1     2     4.0      0.0   9   8
# 348    health  ...    4.0      4.0   3.0     1     3     4.0      0.0  13  15
# 359   at_home  ...    5.0      NaN   2.0     1     1     4.0      0.0  18  16
# 372     other  ...    3.0      NaN   3.0     1     1     3.0      8.0  13  11
# 385   at_home  ...    NaN      NaN   NaN     1     3     NaN      NaN  10   9
#
#      G3
# 20   15
# 71   10
# 87   14
# 99    8
# 102  14
# 106   8
# 121  15
# 130   0
# 149  10
# 151  14
# 160   0
# 188   9
# 191   9
# 214  10
# 257  11
# 270   9
# 276   9
# 293  18
# 308  12
# 330   8
# 343   0
# 348  15
# 359  16
# 372  11
# 385  10
#
# [25 rows x 34 columns]

# %% [markdown]
# ###   g) You will notice that some rows have several NaNs. Now compute the proportion that these rows constitute of the whole dataset.

# %%
df2 = df.isnull().sum("columns").value_counts()
df3 = (df2[df2.index > 1] / sum(df2))
val = float(df3.values)
print(val)
# Out:
# 0.012658227848101266

# %% [markdown]
# ## 2. Clean the data

# %% [markdown]
# ### a) As you have conversed with a domain expert you both agree that there are too many missing data to fill in and the proportion is small enough to be safe to just remove.
# Now remove these rows and use your missing-value utility function visualize the remaining NaNs.

# %%
df4 = df.copy()


df4 = df4.drop(df4[df4.isnull().sum("columns")>1].index)
plot_null_columns(df4)
df4
# Out:
#      Unnamed: 0 school sex   age address famsize Pstatus  Medu  Fedu  \
# 0             0     GP   F  18.0       U     GT3       A     4     4
# 1             1     GP   F  17.0       U     GT3       T     1     1
# 2             2     GP   F  15.0       U     LE3       T     1     1
# 3             3     GP   F  15.0       U     GT3       T     4     2
# 4             4     GP   F  16.0       U     GT3       T     3     3
# ..          ...    ...  ..   ...     ...     ...     ...   ...   ...
# 390         390     MS   M  20.0       U     LE3       A     2     2
# 391         391     MS   M  17.0       U     LE3       T     3     1
# 392         392     MS   M  21.0       R     GT3       T     1     1
# 393         393     MS   M  18.0       R     LE3       T     3     2
# 394         394     MS   M  19.0       U     LE3       T     1     1
#
#          Mjob  ... famrel freetime goout  Dalc  Walc  health absences  G1  G2  \
# 0     at_home  ...    4.0      3.0   4.0     1     1     3.0      6.0   5   6
# 1     at_home  ...    5.0      3.0   3.0     1     1     3.0      4.0   5   5
# 2     at_home  ...    4.0      3.0   2.0     2     3     3.0     10.0   7   8
# 3      health  ...    3.0      2.0   2.0     1     1     5.0      2.0  15  14
# 4       other  ...    4.0      3.0   2.0     1     2     5.0      4.0   6  10
# ..        ...  ...    ...      ...   ...   ...   ...     ...      ...  ..  ..
# 390  services  ...    5.0      5.0   4.0     4     5     4.0     11.0   9   9
# 391  services  ...    2.0      4.0   5.0     3     4     2.0      3.0  14  16
# 392     other  ...    5.0      5.0   3.0     3     3     3.0      3.0  10   8
# 393  services  ...    4.0      4.0   1.0     3     4     5.0      0.0  11  12
# 394     other  ...    3.0      2.0   3.0     3     3     5.0      5.0   8   9
#
#      G3
# 0     6
# 1     6
# 2    10
# 3    15
# 4    10
# ..   ..
# 390   9
# 391  16
# 392   7
# 393  10
# 394   9
#
# [390 rows x 34 columns]

# %% [markdown]
# ### b) The domain expert has told you that you have to fill in the missing age values. Start with visualising the age distribution in the dataset using a histogram.

# %%
import seaborn as sb
sb.histplot(df4, x="age", binwidth=1, binrange=(15, 23) )
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %% [markdown]
# ### c) Check which columns there are in the dataset to see what can be utilised in determining the age.

# %%
df4.columns
# Out:
# Index(['Unnamed: 0', 'school', 'sex', 'age', 'address', 'famsize', 'Pstatus',
#        'Medu', 'Fedu', 'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime',
#        'studytime', 'failures', 'schoolsup', 'famsup', 'paid', 'activities',
#        'nursery', 'higher', 'internet', 'romantic', 'famrel', 'freetime',
#        'goout', 'Dalc', 'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %% [markdown]
# ### d) The column higher seems interesting. Let's see which unique values it can have.

# %%
df4["higher"].unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %% [markdown]
# ### e) Let's see if we can see some connection between age distribution and higher.
#
# Make 3 subplots of age histograms:
#
# - Plot 1: same as b)
# - Plot 2: age distribution when higher is yes
# - Plot 3: age distribution when higher is no

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 3)

sb.histplot(df4, ax=ax[0], x="age", binwidth=1, binrange=(15, 23) )
ax[0].set_title("original" )

sb.histplot(df4[df4["higher"] == 'yes'], ax=ax[1], x="age", binwidth=1, binrange=(15, 23) )
ax[1].set_title("Higher = yes" )

sb.histplot(df4[df4["higher"] == 'no'], ax=ax[2], x="age", binwidth=1, binrange=(15, 23) )
ax[2].set_title("Higher = no" )
# Out:
#      Unnamed: 0 school sex   age address famsize Pstatus  Medu  Fedu  \
# 0             0     GP   F  18.0       U     GT3       A     4     4
# 1             1     GP   F  17.0       U     GT3       T     1     1
# 2             2     GP   F  15.0       U     LE3       T     1     1
# 3             3     GP   F  15.0       U     GT3       T     4     2
# 4             4     GP   F  16.0       U     GT3       T     3     3
# ..          ...    ...  ..   ...     ...     ...     ...   ...   ...
# 390         390     MS   M  20.0       U     LE3       A     2     2
# 391         391     MS   M  17.0       U     LE3       T     3     1
# 392         392     MS   M  21.0       R     GT3       T     1     1
# 393         393     MS   M  18.0       R     LE3       T     3     2
# 394         394     MS   M  19.0       U     LE3       T     1     1
#
#          Mjob  ... famrel freetime goout  Dalc  Walc  health absences  G1  G2  \
# 0     at_home  ...    4.0      3.0   4.0     1     1     3.0      6.0   5   6
# 1     at_home  ...    5.0      3.0   3.0     1     1     3.0      4.0   5   5
# 2     at_home  ...    4.0      3.0   2.0     2     3     3.0     10.0   7   8
# 3      health  ...    3.0      2.0   2.0     1     1     5.0      2.0  15  14
# 4       other  ...    4.0      3.0   2.0     1     2     5.0      4.0   6  10
# ..        ...  ...    ...      ...   ...   ...   ...     ...      ...  ..  ..
# 390  services  ...    5.0      5.0   4.0     4     5     4.0     11.0   9   9
# 391  services  ...    2.0      4.0   5.0     3     4     2.0      3.0  14  16
# 392     other  ...    5.0      5.0   3.0     3     3     3.0      3.0  10   8
# 393  services  ...    4.0      4.0   1.0     3     4     5.0      0.0  11  12
# 394     other  ...    3.0      2.0   3.0     3     3     5.0      5.0   8   9
#
#      G3
# 0     6
# 1     6
# 2    10
# 3    15
# 4    10
# ..   ..
# 390   9
# 391  16
# 392   7
# 393  10
# 394   9
#
# [372 rows x 34 columns]

# %% [markdown]
# ### f) That was hard to find a connection. When reading dataset source we find alcohol consumption, maybe there is some connection between age and alcohol consumption.
#
# - Dalc - workday alcohol consumption (numeric: from 1 - very low to 5 - very high)
# - Walc - weekend alcohol consumption (numeric: from 1 - very low to 5 - very high)
#
#   Start with creating a new column called Alcohol, which is a sum of Dalc and Walc columns

# %%
df5 = df4.copy()
df5.insert(loc= 29, column="Alcohol", value=(df5["Dalc"] + df5["Walc"]))

df5
# Out:
#      Unnamed: 0 school sex   age address famsize Pstatus  Medu  Fedu  \
# 0             0     GP   F  18.0       U     GT3       A     4     4
# 1             1     GP   F  17.0       U     GT3       T     1     1
# 2             2     GP   F  15.0       U     LE3       T     1     1
# 3             3     GP   F  15.0       U     GT3       T     4     2
# 4             4     GP   F  16.0       U     GT3       T     3     3
# ..          ...    ...  ..   ...     ...     ...     ...   ...   ...
# 390         390     MS   M  20.0       U     LE3       A     2     2
# 391         391     MS   M  17.0       U     LE3       T     3     1
# 392         392     MS   M  21.0       R     GT3       T     1     1
# 393         393     MS   M  18.0       R     LE3       T     3     2
# 394         394     MS   M  19.0       U     LE3       T     1     1
#
#          Mjob  ... freetime goout Dalc  Walc  Alcohol  health absences  G1  \
# 0     at_home  ...      3.0   4.0    1     1        2     3.0      6.0   5
# 1     at_home  ...      3.0   3.0    1     1        2     3.0      4.0   5
# 2     at_home  ...      3.0   2.0    2     3        5     3.0     10.0   7
# 3      health  ...      2.0   2.0    1     1        2     5.0      2.0  15
# 4       other  ...      3.0   2.0    1     2        3     5.0      4.0   6
# ..        ...  ...      ...   ...  ...   ...      ...     ...      ...  ..
# 390  services  ...      5.0   4.0    4     5        9     4.0     11.0   9
# 391  services  ...      4.0   5.0    3     4        7     2.0      3.0  14
# 392     other  ...      5.0   3.0    3     3        6     3.0      3.0  10
# 393  services  ...      4.0   1.0    3     4        7     5.0      0.0  11
# 394     other  ...      2.0   3.0    3     3        6     5.0      5.0   8
#
#      G2  G3
# 0     6   6
# 1     5   6
# 2     8  10
# 3    14  15
# 4    10  10
# ..   ..  ..
# 390   9   9
# 391  16  16
# 392   8   7
# 393  12  10
# 394   9   9
#
# [390 rows x 35 columns]

# %% [markdown]
# ### g) Make a barchart for alcohol consumption vs age.

# %%
sb.barplot(data = df5, x="age", y="Alcohol")
# Out:
# <AxesSubplot:xlabel='age', ylabel='Alcohol'>

# %% [markdown]
# ### h) We see that older students tend to drink more, but notice how few 20-22 year-old students we have in the dataset. We can definitely exclude them when computing the missing values. However there are also few 19 year-old students in the dataset, say for simplicity that we can exclude them as well. This leaves:
#
# - alcohol level >= 4 -> 16, 17 or 18 years old -> take median to simplify
# - alcohol level < 4 -> 15 years old
#
# Fill these in and visualize missing values.
#
# Note: could make more stringent by computing percentages based on the distribution

# %%
df6 = df5.copy()
median_ålder = float(df6[(16 <= df6["age"]) & (df6["age"] < 19)]["age"].median())
df6.loc[((df6["age"].isnull()) & (df6["Alcohol"] >= 4)), "age"] = median_ålder
df6.loc[((df6["age"].isnull()) & (df6["Alcohol"] < 4)), "age"] = 15

plot_null_columns(df6)

# %% [markdown]
# # 3. Clean freetime column (**)
# Now there are missing data on freetime that needs to be filled.
#
# * Try yourself and find reasonable approaches for how you would fill those missing data.
# * Document what you have tried and different findings
# * Combine suitable visualizations with pandas methods

# %%
df6
# Out:
#      Unnamed: 0 school sex   age address famsize Pstatus  Medu  Fedu  \
# 0             0     GP   F  18.0       U     GT3       A     4     4
# 1             1     GP   F  17.0       U     GT3       T     1     1
# 2             2     GP   F  15.0       U     LE3       T     1     1
# 3             3     GP   F  15.0       U     GT3       T     4     2
# 4             4     GP   F  16.0       U     GT3       T     3     3
# ..          ...    ...  ..   ...     ...     ...     ...   ...   ...
# 390         390     MS   M  20.0       U     LE3       A     2     2
# 391         391     MS   M  17.0       U     LE3       T     3     1
# 392         392     MS   M  21.0       R     GT3       T     1     1
# 393         393     MS   M  18.0       R     LE3       T     3     2
# 394         394     MS   M  19.0       U     LE3       T     1     1
#
#          Mjob  ... freetime goout Dalc  Walc  Alcohol  health absences  G1  \
# 0     at_home  ...      3.0   4.0    1     1        2     3.0      6.0   5
# 1     at_home  ...      3.0   3.0    1     1        2     3.0      4.0   5
# 2     at_home  ...      3.0   2.0    2     3        5     3.0     10.0   7
# 3      health  ...      2.0   2.0    1     1        2     5.0      2.0  15
# 4       other  ...      3.0   2.0    1     2        3     5.0      4.0   6
# ..        ...  ...      ...   ...  ...   ...      ...     ...      ...  ..
# 390  services  ...      5.0   4.0    4     5        9     4.0     11.0   9
# 391  services  ...      4.0   5.0    3     4        7     2.0      3.0  14
# 392     other  ...      5.0   3.0    3     3        6     3.0      3.0  10
# 393  services  ...      4.0   1.0    3     4        7     5.0      0.0  11
# 394     other  ...      2.0   3.0    3     3        6     5.0      5.0   8
#
#      G2  G3
# 0     6   6
# 1     5   6
# 2     8  10
# 3    14  15
# 4    10  10
# ..   ..  ..
# 390   9   9
# 391  16  16
# 392   8   7
# 393  12  10
# 394   9   9
#
# [390 rows x 35 columns]

# %%
df6.columns
# Out:
# Index(['Unnamed: 0', 'school', 'sex', 'age', 'address', 'famsize', 'Pstatus',
#        'Medu', 'Fedu', 'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime',
#        'studytime', 'failures', 'schoolsup', 'famsup', 'paid', 'activities',
#        'nursery', 'higher', 'internet', 'romantic', 'famrel', 'freetime',
#        'goout', 'Dalc', 'Walc', 'Alcohol', 'health', 'absences', 'G1', 'G2',
#        'G3'],
#       dtype='object')

# %%
df6["address"].unique()
# Out:
# array(['U', 'R'], dtype=object)

# %%
def apa(col: str, x: str, alt1, alt2, binrange  = None):
    fig, ax = plt.subplots(1, 3)

    sb.histplot(df6, ax=ax[0], x=x, binwidth=1, binrange=binrange) 
    ax[0].set_title("original" )

    sb.histplot(df6[df6[col] == alt1], ax=ax[1], x=x, binwidth=1, binrange=binrange)
    ax[1].set_title(alt1 )

    sb.histplot(df6[df6[col] == alt2], ax=ax[2], x=x, binwidth=1, binrange=binrange) 
    ax[2].set_title(alt2)

    fig.suptitle(col)

sb.histplot(df6, x="freetime", binwidth=1, binrange=(0, 6)) 
apa("school", "freetime", "GP", "MS", (0, 6) )
apa("sex", "freetime", 'F', 'M', (0, 6) )

fig, ax = plt.figure(), plt.axes()
sb.histplot(df6, ax=ax, x="age", y= "freetime", binwidth=1) 
fig.suptitle("age")
apa("address", "freetime", 'U', 'R', (0, 6) )

# %%
apa("traveltime", "freetime", 1, 2, (0, 6) )
apa("traveltime", "freetime", 3, 4, (0, 6) )
apa("studytime", "freetime", 1, 2, (0, 6) )
apa("studytime", "freetime", 3, 4, (0, 6) )

apa("activities", "freetime", "no", "yes", (0, 6) )

apa("goout", "freetime", 1, 2, (0, 6) )
apa("goout", "freetime", 3, 4, (0, 6) )
apa("goout", "freetime", 5, 0, (0, 6) )
